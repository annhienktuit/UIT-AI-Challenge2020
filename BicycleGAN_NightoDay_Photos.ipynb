# %% [markdown]
# <a href="https://colab.research.google.com/github/annhienktuit/UIT-AI-Challenge2020/blob/master/BicycleGAN_NightoDay_Photos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !git clone -b master --single-branch https://github.com/junyanz/BicycleGAN.git
# Out:
# Cloning into 'BicycleGAN'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 609 (delta 15), reused 21 (delta 8), pack-reused 575
# Receiving objects: 100% (609/609), 11.98 MiB | 7.29 MiB/s, done.
# Resolving deltas: 100% (367/367), done.

# %%
cd BicycleGAN
# Out:
# /content/BicycleGAN

# %%
# !pip install -r /content/BicycleGAN/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 5.8MB/s
# ...
#      |████████████████████████████████| 204kB 18.7MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655250 sha256=3e4559692c642ec003f76273d2c524671eb3aad0ff8a9d4a1cdec22c33df9b47
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5712 sha256=5ec5420c2bfb3946f5305f8e14ba6f9bdd01da4e3a9f9676fecfc50086b6ff9a
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
# !/content/BicycleGAN/datasets/download_dataset.sh night2day
# Out:
# Streaming output truncated to the last 5000 lines.
# night2day/train/90_7568_to_7560.jpg
# night2day/train/90_7568_to_7561.jpg
# night2day/train/90_7568_to_7562.jpg
# night2day/train/90_7568_to_7564.jpg
# night2day/train/90_7568_to_7566.jpg
# night2day/train/90_7618_to_7603.jpg
# night2day/train/90_7618_to_7604.jpg
# night2day/train/90_7618_to_7605.jpg
# night2day/train/90_7618_to_7606.jpg
# night2day/train/90_7618_to_7607.jpg
# night2day/train/90_7618_to_7609.jpg
# night2day/train/90_7618_to_7611.jpg
# night2day/train/90_7618_to_7612.jpg
# night2day/train/90_7618_to_7613.jpg
# night2day/train/90_7618_to_7614.jpg
# night2day/train/90_7618_to_7617.jpg
# night2day/train/90_7618_to_7619.jpg
# night2day/train/90_7618_to_7620.jpg
# night2day/train/90_7618_to_7621.jpg
# night2day/train/90_7618_to_7622.jpg
# night2day/train/90_7618_to_7624.jpg
# night2day/train/90_7623_to_7546.jpg
# night2day/train/90_7623_to_7547.jpg
# night2day/train/90_7623_to_7548.jpg
# ...

# %%
cd /content/BicycleGAN/pretrained_models/
# Out:
# /content/BicycleGAN/pretrained_models

# %%
# !chmod 755 download_model.sh

# %%
# !/content/BicycleGAN/pretrained_models/download_model.sh night2day
# Out:
# Note: available models are edges2shoes, edges2handbags, night2day, maps, and facades
# downloading [night2day]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2020-08-21 03:45:18--  http://efrosgans.eecs.berkeley.edu/BicycleGAN//models/night2day_net_G.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.189.73
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.189.73|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 219226198 (209M)
# Saving to: ‘./pretrained_models/night2day/latest_net_G.pth’
#
# ./pretrained_models 100%[===================>] 209.07M  21.2MB/s    in 16s
#
# 2020-08-21 03:45:35 (12.7 MB/s) - ‘./pretrained_models/night2day/latest_net_G.pth’ saved [219226198/219226198]
#
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# ...

# %%
cd /content/BicycleGAN/datasets
# Out:
# /content/BicycleGAN/datasets

# %%
# !/content/BicycleGAN/scripts/test_night2day.sh
# Out:
# ++ RESULTS_DIR=/content/results
# ++ G_PATH=/content/BicycleGAN/pretrained_models/pretrained_models/night2day/latest_net_G.pth
# ++ E_PATH=/content/BicycleGAN/pretrained_models/pretrained_models/night2day/latest_net_E.pth
# ++ CLASS=night2day
# ++ DIRECTION=AtoB
# ++ LOAD_SIZE=286
# ++ CROP_SIZE=256
# ++ INPUT_NC=3
# ++ ASPECT_RATIO=1.4
# ++ GPU_ID=0
# ++ NUM_TEST=10
# ++ NUM_SAMPLES=10
# ++ CUDA_VISIBLE_DEVICES=0
# ++ python /content/BicycleGAN/test.py --dataroot /content/datasets/night2day/ --results_dir /content/results --checkpoints_dir /content/BicycleGAN/pretrained_models/pretrained_models/ --name night2day --direction AtoB --load_size 286 --crop_size 256 --input_nc 3 --num_test 10 --n_samples 10 --aspect_ratio 1.4 --center_crop --no_flip
# ----------------- Options ---------------
#              aspect_ratio: 1.4                           	[default: 1.0]
#                batch_size: 2
#               center_crop: True                          	[default: False]
# ...

# %%
# !/content/BicycleGAN/scripts/video_edges2shoes.sh
# Out:
# ++ RESULTS_DIR=/content/results/videos
# ++ G_PATH=/content/BicycleGAN/pretrained_models/pretrained_models/night2day/latest_net_G.pth
# ++ CLASS=night2day
# ++ DIRECTION=AtoB
# ++ LOAD_SIZE=256
# ++ CROP_SIZE=256
# ++ INPUT_NC=3
# ++ GPU_ID=0
# ++ NUM_TEST=10
# ++ NUM_SAMPLES=10
# ++ CUDA_VISIBLE_DEVICES=0
# ++ python /content/BicycleGAN/video.py --dataroot /content/datasets/night2day/ --results_dir /content/results/videos --checkpoints_dir /content/BicycleGAN/pretrained_models/pretrained_models/ --name night2day --direction AtoB --load_size 256 --crop_size 256 --input_nc 3 --num_test 10 --n_samples 10 --center_crop --no_flip
# ----------------- Options ---------------
#                align_mode: horizontal
#                batch_size: 2
#                    border: 0                             	[default: 0]
#               center_crop: True                          	[default: False]
# ...
